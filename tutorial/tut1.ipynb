# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = cv2.imread('C:\\Users\\Asus\\OPENCV_UDEMY\\Computer-Vision-with-Python\\DATA\\00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %% [markdown]
# Matpltlib = 'Red green Blue';
# Open CV  = 'Blue , green , red'

# %%
img2 = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img2)

# %%
img2.shape
# Out:
# (1300, 1950, 3)

# %%
img_gray = cv2.imread('C:\\Users\\Asus\\OPENCV_UDEMY\\Computer-Vision-with-Python\\DATA\\00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray,cmap = 'magma')

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %% [markdown]
# <h3>resizing the shapes</h3>

# %%
### for resizing the shapes 

h_ratio = 0.2
w_ratio = 0.8

# %%
plt.imshow(img2)

# %%
#resizing the image
new_image = cv2.resize(img2 , (0,0) , img2 ,  w_ratio,h_ratio)

# %%
plt.imshow(new_image)

# %%
new_image.shape
# Out:
# (260, 1560, 3)

# %%
img2.shape
# Out:
# (1300, 1950, 3)

# %%
new_image = cv2.flip(img2,-1)

# %% [markdown]
# 0 for x_axis and 1 for y_axis and -1 for both x axis and y axis

# %%
plt.imshow(new_image)

# %%
type(new_image)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg' , new_image)
# Out:
# True

# %%
fig  = plt.figure(figsize = (10,7))
ax = fig.add_subplot(111)
ax.imshow(img2)
